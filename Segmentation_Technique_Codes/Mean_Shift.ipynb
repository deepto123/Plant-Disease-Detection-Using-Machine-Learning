# %% [markdown]
# # **Step 1: Importing the required libraries**

# %%
import cv2
import os
import glob
import numpy as np
import matplotlib.pyplot as plt
from skimage.io import imsave
from google.colab.patches import cv2_imshow 
from skimage.color import rgb2lab
from sklearn.cluster import MeanShift, estimate_bandwidth

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# # **Step 2: Performing Mean Shift Segmentation technique on Enhanced Covid-19 Chest X-ray images**

# %%
folder='/content/drive/MyDrive/Plant_disease_dataset/Apple/Apple___healthy'
def load_images_from_folder(folder):
    images = []
count=0
for filename in os.listdir(folder):
   a = cv2.imread(os.path.join(folder,filename))
   #cv2_imshow(a)
   fimage = cv2.cvtColor(a, cv2.COLOR_BGR2LAB)
   originShape = fimage.shape
   flatImg=np.reshape(fimage, [-1, 3])
   
   # Estimate bandwidth for meanshift algorithm    
   bandwidth = estimate_bandwidth(flatImg, quantile=0.1, n_samples=100)    
   ms = MeanShift(bandwidth = bandwidth, bin_seeding=True)
   
   # Performing meanshift on flatI mg    
   ms.fit(flatImg)
   
   # (r,g,b) vectors corresponding to the different clusters after meanshift    
   labels=ms.labels_
   
   # Remaining colors after meanshift    
   cluster_centers = ms.cluster_centers_    
   
   # Finding and diplaying the number of clusters    
   labels_unique = np.unique(labels)    
   n_clusters_ = len(labels_unique)    
   #print("number of estimated clusters : %d" % n_clusters_)
   count+=1
   segmentedImg = np.reshape(labels, originShape[:2])
   imsave('/content/drive/MyDrive/Segmented_images/Mean-Shift/Apple_healthy_Segmented/Mean_shift_output'+str(count)+'.JPG',segmentedImg)
   #cv2.imwrite('/content/drive/MyDrive/NIT DGP Internship/output/output'+str(count)+'.png', segmentedImg)
   #cv2_imshow(segmentedImg)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:31: UserWarning: /content/drive/MyDrive/Segmented_images/Mean-Shift/Apple_healthy_Segmented/Mean_shift_output1.JPG is a low contrast image
# WARNING:root:Lossy conversion from int64 to uint8. Range [0, 7]. Convert image to uint8 prior to saving to suppress this warning.
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:31: UserWarning: /content/drive/MyDrive/Segmented_images/Mean-Shift/Apple_healthy_Segmented/Mean_shift_output2.JPG is a low contrast image
# WARNING:root:Lossy conversion from int64 to uint8. Range [0, 5]. Convert image to uint8 prior to saving to suppress this warning.
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:31: UserWarning: /content/drive/MyDrive/Segmented_images/Mean-Shift/Apple_healthy_Segmented/Mean_shift_output3.JPG is a low contrast image
# WARNING:root:Lossy conversion from int64 to uint8. Range [0, 4]. Convert image to uint8 prior to saving to suppress this warning.
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:31: UserWarning: /content/drive/MyDrive/Segmented_images/Mean-Shift/Apple_healthy_Segmented/Mean_shift_output4.JPG is a low contrast image
# WARNING:root:Lossy conversion from int64 to uint8. Range [0, 7]. Convert image to uint8 prior to saving to suppress this warning.
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:31: UserWarning: /content/drive/MyDrive/Segmented_images/Mean-Shift/Apple_healthy_Segmented/Mean_shift_output5.JPG is a low contrast image
# WARNING:root:Lossy conversion from int64 to uint8. Range [0, 2]. Convert image to uint8 prior to saving to suppress this warning.
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:31: UserWarning: /content/drive/MyDrive/Segmented_images/Mean-Shift/Apple_healthy_Segmented/Mean_shift_output6.JPG is a low contrast image
# WARNING:root:Lossy conversion from int64 to uint8. Range [0, 16]. Convert image to uint8 prior to saving to suppress this warning.
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:31: UserWarning: /content/drive/MyDrive/Segmented_images/Mean-Shift/Apple_healthy_Segmented/Mean_shift_output7.JPG is a low contrast image
# WARNING:root:Lossy conversion from int64 to uint8. Range [0, 6]. Convert image to uint8 prior to saving to suppress this warning.
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:31: UserWarning: /content/drive/MyDrive/Segmented_images/Mean-Shift/Apple_healthy_Segmented/Mean_shift_output8.JPG is a low contrast image
# WARNING:root:Lossy conversion from int64 to uint8. Range [0, 5]. Convert image to uint8 prior to saving to suppress this warning.
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:31: UserWarning: /content/drive/MyDrive/Segmented_images/Mean-Shift/Apple_healthy_Segmented/Mean_shift_output9.JPG is a low contrast image
# WARNING:root:Lossy conversion from int64 to uint8. Range [0, 7]. Convert image to uint8 prior to saving to suppress this warning.
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:31: UserWarning: /content/drive/MyDrive/Segmented_images/Mean-Shift/Apple_healthy_Segmented/Mean_shift_output10.JPG is a low contrast image
# WARNING:root:Lossy conversion from int64 to uint8. Range [0, 4]. Convert image to uint8 prior to saving to suppress this warning.
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:31: UserWarning: /content/drive/MyDrive/Segmented_images/Mean-Shift/Apple_healthy_Segmented/Mean_shift_output11.JPG is a low contrast image
# WARNING:root:Lossy conversion from int64 to uint8. Range [0, 4]. Convert image to uint8 prior to saving to suppress this warning.
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:31: UserWarning: /content/drive/MyDrive/Segmented_images/Mean-Shift/Apple_healthy_Segmented/Mean_shift_output12.JPG is a low contrast image
# WARNING:root:Lossy conversion from int64 to uint8. Range [0, 5]. Convert image to uint8 prior to saving to suppress this warning.
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:31: UserWarning: /content/drive/MyDrive/Segmented_images/Mean-Shift/Apple_healthy_Segmented/Mean_shift_output13.JPG is a low contrast image
# WARNING:root:Lossy conversion from int64 to uint8. Range [0, 6]. Convert image to uint8 prior to saving to suppress this warning.
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:31: UserWarning: /content/drive/MyDrive/Segmented_images/Mean-Shift/Apple_healthy_Segmented/Mean_shift_output14.JPG is a low contrast image
# WARNING:root:Lossy conversion from int64 to uint8. Range [0, 5]. Convert image to uint8 prior to saving to suppress this warning.
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:31: UserWarning: /content/drive/MyDrive/Segmented_images/Mean-Shift/Apple_healthy_Segmented/Mean_shift_output15.JPG is a low contrast image
# WARNING:root:Lossy conversion from int64 to uint8. Range [0, 10]. Convert image to uint8 prior to saving to suppress this warning.
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:31: UserWarning: /content/drive/MyDrive/Segmented_images/Mean-Shift/Apple_healthy_Segmented/Mean_shift_output16.JPG is a low contrast image
# WARNING:root:Lossy conversion from int64 to uint8. Range [0, 7]. Convert image to uint8 prior to saving to suppress this warning.
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:31: UserWarning: /content/drive/MyDrive/Segmented_images/Mean-Shift/Apple_healthy_Segmented/Mean_shift_output17.JPG is a low contrast image
# WARNING:root:Lossy conversion from int64 to uint8. Range [0, 6]. Convert image to uint8 prior to saving to suppress this warning.
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:31: UserWarning: /content/drive/MyDrive/Segmented_images/Mean-Shift/Apple_healthy_Segmented/Mean_shift_output18.JPG is a low contrast image
# WARNING:root:Lossy conversion from int64 to uint8. Range [0, 6]. Convert image to uint8 prior to saving to suppress this warning.
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:31: UserWarning: /content/drive/MyDrive/Segmented_images/Mean-Shift/Apple_healthy_Segmented/Mean_shift_output19.JPG is a low contrast image
# WARNING:root:Lossy conversion from int64 to uint8. Range [0, 5]. Convert image to uint8 prior to saving to suppress this warning.
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:31: UserWarning: /content/drive/MyDrive/Segmented_images/Mean-Shift/Apple_healthy_Segmented/Mean_shift_output20.JPG is a low contrast image
# WARNING:root:Lossy conversion from int64 to uint8. Range [0, 3]. Convert image to uint8 prior to saving to suppress this warning.
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:31: UserWarning: /content/drive/MyDrive/Segmented_images/Mean-Shift/Apple_healthy_Segmented/Mean_shift_output21.JPG is a low contrast image
# WARNING:root:Lossy conversion from int64 to uint8. Range [0, 5]. Convert image to uint8 prior to saving to suppress this warning.
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:31: UserWarning: /content/drive/MyDrive/Segmented_images/Mean-Shift/Apple_healthy_Segmented/Mean_shift_output22.JPG is a low contrast image
# WARNING:root:Lossy conversion from int64 to uint8. Range [0, 4]. Convert image to uint8 prior to saving to suppress this warning.
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:31: UserWarning: /content/drive/MyDrive/Segmented_images/Mean-Shift/Apple_healthy_Segmented/Mean_shift_output23.JPG is a low contrast image
# WARNING:root:Lossy conversion from int64 to uint8. Range [0, 3]. Convert image to uint8 prior to saving to suppress this warning.
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:31: UserWarning: /content/drive/MyDrive/Segmented_images/Mean-Shift/Apple_healthy_Segmented/Mean_shift_output24.JPG is a low contrast image
# WARNING:root:Lossy conversion from int64 to uint8. Range [0, 9]. Convert image to uint8 prior to saving to suppress this warning.
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:31: UserWarning: /content/drive/MyDrive/Segmented_images/Mean-Shift/Apple_healthy_Segmented/Mean_shift_output25.JPG is a low contrast image
# WARNING:root:Lossy conversion from int64 to uint8. Range [0, 6]. Convert image to uint8 prior to saving to suppress this warning.
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:31: UserWarning: /content/drive/MyDrive/Segmented_images/Mean-Shift/Apple_healthy_Segmented/Mean_shift_output26.JPG is a low contrast image
# WARNING:root:Lossy conversion from int64 to uint8. Range [0, 3]. Convert image to uint8 prior to saving to suppress this warning.
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:31: UserWarning: /content/drive/MyDrive/Segmented_images/Mean-Shift/Apple_healthy_Segmented/Mean_shift_output27.JPG is a low contrast image
# WARNING:root:Lossy conversion from int64 to uint8. Range [0, 2]. Convert image to uint8 prior to saving to suppress this warning.
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:31: UserWarning: /content/drive/MyDrive/Segmented_images/Mean-Shift/Apple_healthy_Segmented/Mean_shift_output28.JPG is a low contrast image
# WARNING:root:Lossy conversion from int64 to uint8. Range [0, 4]. Convert image to uint8 prior to saving to suppress this warning.
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:31: UserWarning: /content/drive/MyDrive/Segmented_images/Mean-Shift/Apple_healthy_Segmented/Mean_shift_output29.JPG is a low contrast image
# WARNING:root:Lossy conversion from int64 to uint8. Range [0, 4]. Convert image to uint8 prior to saving to suppress this warning.
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:31: UserWarning: /content/drive/MyDrive/Segmented_images/Mean-Shift/Apple_healthy_Segmented/Mean_shift_output30.JPG is a low contrast image
# WARNING:root:Lossy conversion from int64 to uint8. Range [0, 5]. Convert image to uint8 prior to saving to suppress this warning.
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:31: UserWarning: /content/drive/MyDrive/Segmented_images/Mean-Shift/Apple_healthy_Segmented/Mean_shift_output31.JPG is a low contrast image
# WARNING:root:Lossy conversion from int64 to uint8. Range [0, 7]. Convert image to uint8 prior to saving to suppress this warning.
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:31: UserWarning: /content/drive/MyDrive/Segmented_images/Mean-Shift/Apple_healthy_Segmented/Mean_shift_output32.JPG is a low contrast image
# WARNING:root:Lossy conversion from int64 to uint8. Range [0, 5]. Convert image to uint8 prior to saving to suppress this warning.
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:31: UserWarning: /content/drive/MyDrive/Segmented_images/Mean-Shift/Apple_healthy_Segmented/Mean_shift_output33.JPG is a low contrast image
# WARNING:root:Lossy conversion from int64 to uint8. Range [0, 4]. Convert image to uint8 prior to saving to suppress this warning.
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:31: UserWarning: /content/drive/MyDrive/Segmented_images/Mean-Shift/Apple_healthy_Segmented/Mean_shift_output34.JPG is a low contrast image
# WARNING:root:Lossy conversion from int64 to uint8. Range [0, 6]. Convert image to uint8 prior to saving to suppress this warning.
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:31: UserWarning: /content/drive/MyDrive/Segmented_images/Mean-Shift/Apple_healthy_Segmented/Mean_shift_output35.JPG is a low contrast image
# WARNING:root:Lossy conversion from int64 to uint8. Range [0, 6]. Convert image to uint8 prior to saving to suppress this warning.
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:31: UserWarning: /content/drive/MyDrive/Segmented_images/Mean-Shift/Apple_healthy_Segmented/Mean_shift_output36.JPG is a low contrast image
# WARNING:root:Lossy conversion from int64 to uint8. Range [0, 5]. Convert image to uint8 prior to saving to suppress this warning.
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:31: UserWarning: /content/drive/MyDrive/Segmented_images/Mean-Shift/Apple_healthy_Segmented/Mean_shift_output37.JPG is a low contrast image
# WARNING:root:Lossy conversion from int64 to uint8. Range [0, 4]. Convert image to uint8 prior to saving to suppress this warning.
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:31: UserWarning: /content/drive/MyDrive/Segmented_images/Mean-Shift/Apple_healthy_Segmented/Mean_shift_output38.JPG is a low contrast image
# WARNING:root:Lossy conversion from int64 to uint8. Range [0, 2]. Convert image to uint8 prior to saving to suppress this warning.
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:31: UserWarning: /content/drive/MyDrive/Segmented_images/Mean-Shift/Apple_healthy_Segmented/Mean_shift_output39.JPG is a low contrast image
# WARNING:root:Lossy conversion from int64 to uint8. Range [0, 3]. Convert image to uint8 prior to saving to suppress this warning.
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:31: UserWarning: /content/drive/MyDrive/Segmented_images/Mean-Shift/Apple_healthy_Segmented/Mean_shift_output40.JPG is a low contrast image
# WARNING:root:Lossy conversion from int64 to uint8. Range [0, 5]. Convert image to uint8 prior to saving to suppress this warning.
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:31: UserWarning: /content/drive/MyDrive/Segmented_images/Mean-Shift/Apple_healthy_Segmented/Mean_shift_output41.JPG is a low contrast image
# WARNING:root:Lossy conversion from int64 to uint8. Range [0, 7]. Convert image to uint8 prior to saving to suppress this warning.
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:31: UserWarning: /content/drive/MyDrive/Segmented_images/Mean-Shift/Apple_healthy_Segmented/Mean_shift_output42.JPG is a low contrast image
# WARNING:root:Lossy conversion from int64 to uint8. Range [0, 5]. Convert image to uint8 prior to saving to suppress this warning.
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:31: UserWarning: /content/drive/MyDrive/Segmented_images/Mean-Shift/Apple_healthy_Segmented/Mean_shift_output43.JPG is a low contrast image
# WARNING:root:Lossy conversion from int64 to uint8. Range [0, 4]. Convert image to uint8 prior to saving to suppress this warning.
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:31: UserWarning: /content/drive/MyDrive/Segmented_images/Mean-Shift/Apple_healthy_Segmented/Mean_shift_output44.JPG is a low contrast image
# WARNING:root:Lossy conversion from int64 to uint8. Range [0, 5]. Convert image to uint8 prior to saving to suppress this warning.
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:31: UserWarning: /content/drive/MyDrive/Segmented_images/Mean-Shift/Apple_healthy_Segmented/Mean_shift_output45.JPG is a low contrast image
# WARNING:root:Lossy conversion from int64 to uint8. Range [0, 5]. Convert image to uint8 prior to saving to suppress this warning.
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:31: UserWarning: /content/drive/MyDrive/Segmented_images/Mean-Shift/Apple_healthy_Segmented/Mean_shift_output46.JPG is a low contrast image
# WARNING:root:Lossy conversion from int64 to uint8. Range [0, 2]. Convert image to uint8 prior to saving to suppress this warning.
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:31: UserWarning: /content/drive/MyDrive/Segmented_images/Mean-Shift/Apple_healthy_Segmented/Mean_shift_output47.JPG is a low contrast image
# WARNING:root:Lossy conversion from int64 to uint8. Range [0, 4]. Convert image to uint8 prior to saving to suppress this warning.
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:31: UserWarning: /content/drive/MyDrive/Segmented_images/Mean-Shift/Apple_healthy_Segmented/Mean_shift_output48.JPG is a low contrast image
# WARNING:root:Lossy conversion from int64 to uint8. Range [0, 3]. Convert image to uint8 prior to saving to suppress this warning.
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:31: UserWarning: /content/drive/MyDrive/Segmented_images/Mean-Shift/Apple_healthy_Segmented/Mean_shift_output49.JPG is a low contrast image
# WARNING:root:Lossy conversion from int64 to uint8. Range [0, 5]. Convert image to uint8 prior to saving to suppress this warning.
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:31: UserWarning: /content/drive/MyDrive/Segmented_images/Mean-Shift/Apple_healthy_Segmented/Mean_shift_output50.JPG is a low contrast image
# WARNING:root:Lossy conversion from int64 to uint8. Range [0, 8]. Convert image to uint8 prior to saving to suppress this warning.

# %%
if __name__=="__main__":
    load_images_from_folder(folder)
