# %% [markdown]
# # **Step 1: Importing the required libraries**

# %%
import cv2
import os
import numpy as np
import matplotlib.pyplot as plt
from google.colab.patches import cv2_imshow
from PIL import Image 
from PIL import ImageFilter

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# # **Step 2: Performing K-means Segmentation technique on Enhanced Covid-19 Chest X-ray images**

# %%
def KMeans():
  inPath ="/content/drive/MyDrive/Plant_disease_dataset/Apple/Apple___healthy"
  outPath ="/content/drive/MyDrive/Segmented_images/K-means_Clustering/Apple_healthy_Segmented"
  for imagePath in os.listdir(inPath):
    inputPath=os.path.join(inPath, imagePath)
    img=Image.open(inputPath)
 
    numpy_image = np.array(img)
    opencvImage = cv2.cvtColor(numpy_image, cv2.COLOR_BGR2GRAY)
    pixel_values = opencvImage.reshape((-1, 2))

    pixel_values = np.float32(pixel_values)
    criteria = (cv2.TERM_CRITERIA_EPS + cv2.TERM_CRITERIA_MAX_ITER, 100, 0.2)
    k = 7
    _, labels, (centers) = cv2.kmeans(pixel_values, k, None, criteria, 10, cv2.KMEANS_RANDOM_CENTERS)
    centers = np.uint8(centers)

    labels = labels.flatten()
    segmented_image = centers[labels.flatten()]
    segmented_image = segmented_image.reshape(opencvImage.shape)

    fullOutPath=os.path.join(outPath,'segmentedKMeans_'+imagePath)
    im_pil = Image.fromarray(segmented_image)
    im_pil.save(fullOutPath)
    print(fullOutPath)

# %%
def main():
  KMeans()
if __name__=='__main__':
  main()
# Out:
# /content/drive/MyDrive/Segmented_images/K-means_Clustering/Apple_healthy_Segmented/segmentedKMeans_15bacfc9-1875-48b3-9b91-8b60f030d7ca___RS_HL 7240.JPG
# /content/drive/MyDrive/Segmented_images/K-means_Clustering/Apple_healthy_Segmented/segmentedKMeans_017fd21b-142f-4988-849a-5fd316ea9a1b___RS_HL 6279.JPG
# /content/drive/MyDrive/Segmented_images/K-means_Clustering/Apple_healthy_Segmented/segmentedKMeans_13cdbdbe-be7f-463c-9085-9ae160412772___RS_HL 6286.JPG
# /content/drive/MyDrive/Segmented_images/K-means_Clustering/Apple_healthy_Segmented/segmentedKMeans_14c691eb-78de-417f-8832-93427151a6e1___RS_HL 8090.JPG
# /content/drive/MyDrive/Segmented_images/K-means_Clustering/Apple_healthy_Segmented/segmentedKMeans_18a10d55-e00c-4bb7-9ea6-d11bf0de070e___RS_HL 7252.JPG
# /content/drive/MyDrive/Segmented_images/K-means_Clustering/Apple_healthy_Segmented/segmentedKMeans_13c8382b-ca6c-45f5-a6d0-acd67fb28651___RS_HL 7284.JPG
# /content/drive/MyDrive/Segmented_images/K-means_Clustering/Apple_healthy_Segmented/segmentedKMeans_14a71f70-0cd9-416c-88c9-5a76e0473e07___RS_HL 7884.JPG
# /content/drive/MyDrive/Segmented_images/K-means_Clustering/Apple_healthy_Segmented/segmentedKMeans_13dba956-2c74-400e-a2ac-b06baeee5e38___RS_HL 7571.JPG
# /content/drive/MyDrive/Segmented_images/K-means_Clustering/Apple_healthy_Segmented/segmentedKMeans_13a06d54-2bd9-4bd0-a260-1c193ac4caa8___RS_HL 6293.JPG
# /content/drive/MyDrive/Segmented_images/K-means_Clustering/Apple_healthy_Segmented/segmentedKMeans_11dc8fb3-42f9-4d14-9e20-3252e18eb802___RS_HL 6278.JPG
# /content/drive/MyDrive/Segmented_images/K-means_Clustering/Apple_healthy_Segmented/segmentedKMeans_10f68987-caf7-4e29-aa26-b48e074212f4___RS_HL 6130.JPG
# /content/drive/MyDrive/Segmented_images/K-means_Clustering/Apple_healthy_Segmented/segmentedKMeans_15b10e4e-2d9b-463e-85c0-d66ba29c5b49___RS_HL 7506.JPG
# /content/drive/MyDrive/Segmented_images/K-means_Clustering/Apple_healthy_Segmented/segmentedKMeans_20a6a1df-7c88-4c01-bfe0-2110c1eb0324___RS_HL 8133.JPG
# /content/drive/MyDrive/Segmented_images/K-means_Clustering/Apple_healthy_Segmented/segmentedKMeans_10f75d05-fa3e-4b14-b3d8-093292c218e6___RS_HL 7873.JPG
# /content/drive/MyDrive/Segmented_images/K-means_Clustering/Apple_healthy_Segmented/segmentedKMeans_21c42956-0894-43bf-a1b8-787ef33594c2___RS_HL 7686.JPG
# /content/drive/MyDrive/Segmented_images/K-means_Clustering/Apple_healthy_Segmented/segmentedKMeans_20d16569-6237-4038-b6a9-2b2e5375beea___RS_HL 6042.JPG
# /content/drive/MyDrive/Segmented_images/K-means_Clustering/Apple_healthy_Segmented/segmentedKMeans_21c10a73-ebeb-4a16-898b-8b39d9d6eca2___RS_HL 6315.JPG
# /content/drive/MyDrive/Segmented_images/K-means_Clustering/Apple_healthy_Segmented/segmentedKMeans_14bb032e-5462-40e4-9056-0e9c3eb47946___RS_HL 7301.JPG
# /content/drive/MyDrive/Segmented_images/K-means_Clustering/Apple_healthy_Segmented/segmentedKMeans_13bbfa7e-e864-414e-a16b-cb08688604ae___RS_HL 6190.JPG
# /content/drive/MyDrive/Segmented_images/K-means_Clustering/Apple_healthy_Segmented/segmentedKMeans